# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
# x = np.array([[2,1],[3,3],[4,2],[4,4],[5,4],[6,4],[6,6],[7,4],[7,6],[8,7],[10,9],[10,10]])
X= np.array([2,3,4,4,5,6,6,7,7,8,10,10])
Y = np.array([1,3,2,4,4,4,6,4,6,7,9,10])
matriz = np.corrcoef(X,Y)

matriz[0,1]

plt.scatter(X,Y)

plt.title("Diagrama de dispersion")
plt.xlabel("Matematica")
plt.ylabel("Fisica")
# Out:
# Text(0, 0.5, 'Fisica')

# %%
w0 = 0
w1 = 0
print(w0,w1)
# Out:
# 0 0

# %%
import numpy as np

# Inicializar parámetros
w = 0
w_0 = 0
learning_rate = 0.1

# Número de iteraciones
num_iterations = 9
for i in range(num_iterations):
    # Calcular gradientes
    gradient_w = 1008 * w + 144 * w_0 - 862
    gradient_w_0 = 144 * w + 24 * w_0 - 120
    
    # Actualizar parámetros
    w = w - learning_rate * gradient_w
    w_0 = w_0 - learning_rate * gradient_w_0
    

# Resultado final
print(f"Parámetros óptimos: w: {w}, w_0: {w_0}")
# Out:
# Parámetros óptimos: w: 9.889618810047005e+17, w_0: 1.4175274626745315e+17

# %%
#NO SE
