# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn import preprocessing, metrics, model_selection
import time
#from matplotlib import pyplot as plt
from matplotlib import pylab as plt
from sklearn.neural_network import MLPClassifier

# %%
df = pd.read_csv("../Datos/semillas.csv")
df
# Out:
#       Area  Perimetro  Compacidad  LongNucleo  AnchoNucleo  Asimetria  \
# 0    15.26      14.84      0.8710       5.763        3.312      2.221
# 1    14.88      14.57      0.8811       5.554        3.333      1.018
# 2    14.29      14.09      0.9050       5.291        3.337      2.699
# 3    13.84      13.94      0.8955       5.324        3.379      2.259
# 4    16.14      14.99      0.9034       5.658        3.562      1.355
# ..     ...        ...         ...         ...          ...        ...
# 205  12.19      13.20      0.8783       5.137        2.981      3.631
# 206  11.23      12.88      0.8511       5.140        2.795      4.325
# 207  13.20      13.66      0.8883       5.236        3.232      8.315
# 208  11.84      13.21      0.8521       5.175        2.836      3.598
# 209  12.30      13.34      0.8684       5.243        2.974      5.637
#
#      LongSurco  Clase
# 0        5.220  Tipo1
# 1        4.956  Tipo1
# 2        4.825  Tipo1
# 3        4.805  Tipo1
# ...

# %%
X = np.array(df.iloc[:,:-1])
# Out:
# (210, 7)

# %%
# La cantidad de neuronas de la capa de entrada es de 7, la de salida son 3 y la cantidad de arcos con una sola capa oculta seria de 21 arcos
# El error cometido en la predicción:

# Sí. El error (diferencia entre la salida esperada y la salida predicha) afecta directamente la actualización de los pesos. Si el error es positivo, los pesos se ajustarán en una dirección para reducir el error; si el error es negativo, los pesos se ajustarán en la dirección opuesta.
# El valor de la derivada de la función de activación:
# 
# Sí. La derivada de la función de activación (en este caso, "tanh" para la capa oculta y "sigmoid" para la capa de salida) afecta la magnitud y la dirección del ajuste de los pesos. La derivada indica cuán sensible es la salida de la neurona al cambio en la entrada, lo que a su vez influye en la actualización de los pesos. Si la derivada es positiva, el cambio de peso será en una dirección; si es negativa, en la otra.
# Los valores anteriores de los pesos de la red:
# 
# (Chequear) No directamente. Aunque los valores anteriores de los pesos no influyen directamente en la dirección del cambio de los pesos, sí afectan la predicción y el cálculo del error. En consecuencia, los pesos actuales determinan el resultado de la red y, a través de la retropropagación, influyen en cómo se actualizarán los pesos en futuras iteraciones. Sin embargo, no son un factor que determine el signo de la modificación de los pesos en sí.

# Ahora, para la capa oculta, dado que las neuronas de la capa oculta contribuyen a la salida de la neurona de salida que está generando el error, todos los pesos que conectan las neuronas de entrada a las 4 neuronas ocultas se verán afectados. Es decir, los pesos desde las 7 neuronas de entrada hacia cada una de las 4 neuronas ocultas serán modificados.
