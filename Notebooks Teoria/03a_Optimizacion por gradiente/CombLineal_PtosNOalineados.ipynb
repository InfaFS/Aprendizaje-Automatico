# %%
import os
RECURSOS_DIR = "../../Recursos" 
archivos = os.listdir(RECURSOS_DIR )
print(os.getcwd())
# Out:
# c:\Users\facus\OneDrive\Escritorio\Facultad\Segundo cuatri 3 anio\Aprendizaje Automatico\Notebooks Teoria\03a_Optimizacion por gradiente

# %%
# %matplotlib inline
import sys
sys.path.append(RECURSOS_DIR )


import numpy as np
import pandas as pd
import time
#from matplotlib import pyplot as plt
from matplotlib import pylab as plt
from IPython import display

from grafica import *
from ClassNeuronaLineal import NeuronaLineal

# %%
Ptos = np.array([[1,1], [3,2], [5,5], [2,3], [4,3]])
X = Ptos[:,0].reshape(-1,1)
Y = Ptos[:,1]
print(X)
print(Y)
# Out:
# [[1]
#  [3]
#  [5]
#  [2]
#  [4]]
# [1 2 5 3 3]

# %%
nl = NeuronaLineal(alpha=0.01, n_iter=30, cotaE=10e-06, draw=1, title=['X', 'Y'])
# --- utilice random_state=None para que los pesos se inicializacen en forma aleatoria --
nl.fit(X, Y)

# %%
print("W = ", nl.w_)
print("b = ", nl.b_)
# Out:
# W =  [0.90693729]
# b =  0.013590692339912554

# %%
plt.plot(range(1, len(nl.errors_) + 1), nl.errors_, marker='o')
plt.xlabel('Iteraciones')
plt.ylabel('Cantidad de actualizaciones')
plt.show()
